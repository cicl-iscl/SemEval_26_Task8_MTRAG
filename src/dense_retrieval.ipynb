# %%
from pathlib import Path
import pandas as pd

from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval import models
from beir.retrieval.search.dense import DenseRetrievalExactSearch as DRES
from beir.retrieval.evaluation import EvaluateRetrieval
# Out:
# /Users/sandylin/miniconda3/lib/python3.11/site-packages/beir/datasets/data_loader.py:8: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
BASE_DIR = Path(".").resolve()
# 如果以后把 notebook 放到 notebooks/ 之类的子目录，就改成：
# BASE_DIR = Path("..").resolve()
DATASETS = {
    "clapnq": {
        "data_dir": BASE_DIR / "dataset" / "clapnq",
        "faiss_dir": BASE_DIR / "indexes" / "clapnq-bge-faiss",
    },
    "cloud": {
        "data_dir": BASE_DIR / "dataset" / "cloud",
        "faiss_dir": BASE_DIR / "indexes" / "cloud-bge-faiss",
    },
    "fiqa": {
        "data_dir": BASE_DIR / "dataset" / "fiqa",
        "faiss_dir": BASE_DIR / "indexes" / "fiqa-bge-faiss",
    },
    "govt": {
        "data_dir": BASE_DIR / "dataset" / "govt",
        "faiss_dir": BASE_DIR / "indexes" / "govt-bge-faiss",
    },
}

# %%
str(DATASETS["govt"]["data_dir"])
# Out:
# '/Users/sandylin/Challenge in CL/dataset/govt'

# %%
MODEL_NAME = "BAAI/bge-base-en-v1.5"  
BATCH_SIZE = 64 #adjustable
SPLIT = "train"    # 现在 qrels 里是 train.tsv

# initialize embedding model
embedding_model = models.SentenceBERT(MODEL_NAME)

# DenseRetrievalExactSearch 精确搜索
dres_model = DRES(embedding_model, batch_size=BATCH_SIZE)

# EvaluateRetrieval
retriever = EvaluateRetrieval(dres_model, score_function="cos_sim")

K_VALUES = [1, 3, 5, 10]

# %%
def evaluate_dataset(dataset_name: str):
    cfg = DATASETS[dataset_name]
    data_dir = cfg["data_dir"]
    #faiss_dir = cfg["faiss_dir"]

    print(f"Dataset: {dataset_name}")
    print("data_dir :", data_dir)
    #print("faiss_dir:", faiss_dir)

    # 保证目录存在
    #faiss_dir.mkdir(parents=True, exist_ok=True)

    # loading data into beir
    corpus, queries, qrels = GenericDataLoader(
        data_folder=str(data_dir)
    ).load(split=SPLIT) # TODO：这里有些变量名以后可以统一

    print(f"#docs = {len(corpus)}, #queries = {len(queries)}")

    # encode 
    results = retriever.retrieve(
        corpus, 
        queries, 
    )

    # nDCG  Recall 
    print("start evaluation")
    ndcg, _map, recall, precision = retriever.evaluate(qrels, results, K_VALUES)
    print("Done evaluation")

    return {
        "ndcg": ndcg,
        "recall": recall,
    }

# %%
all_metrics = {}

for name in ["clapnq", "cloud", "fiqa", "govt"]:
    all_metrics[name] = evaluate_dataset(name)

all_metrics
# Out:
# Dataset: clapnq
# data_dir : /Users/sandylin/Challenge in CL/dataset/clapnq
# faiss_dir: /Users/sandylin/Challenge in CL/indexes/clapnq-bge-faiss
#   0%|          | 0/183408 [00:00<?, ?it/s]
# #docs = 183408, #queries = 208
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/782 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 all_metrics = {}
#       3 for name in ["clapnq", "cloud", "fiqa", "govt"]:
# ----> 4     all_metrics[name] = evaluate_dataset(name)
#       6 all_metrics
#
# Cell In[4], line 21, in evaluate_dataset(dataset_name)
#      18 print(f"#docs = {len(corpus)}, #queries = {len(queries)}")
#      20 # encode + faiss 检索
# ---> 21 results = retriever.retrieve(
#      22     corpus,
#      23     queries,
#      24 )
#      26 # nDCG  Recall
#      27 print("start evaluation")
#
# File ~/miniconda3/lib/python3.11/site-packages/beir/retrieval/evaluation.py:31, in EvaluateRetrieval.retrieve(self, corpus, queries, **kwargs)
#      29 if not self.retriever:
#      30     raise ValueError("Model/Technique has not been provided!")
# ---> 31 return self.retriever.search(corpus, queries, self.top_k, self.score_function, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/beir/retrieval/search/dense/exact_search.py:88, in DenseRetrievalExactSearch.search(self, corpus, queries, top_k, score_function, return_sorted, **kwargs)
#      85 corpus_end_idx = min(corpus_start_idx + self.corpus_chunk_size, len(corpus))
#      87 # Encode chunk of corpus
# ---> 88 sub_corpus_embeddings = self.model.encode_corpus(
#      89     corpus[corpus_start_idx:corpus_end_idx],
#      90     batch_size=self.batch_size,
#      91     show_progress_bar=self.show_progress_bar,
#      92     convert_to_tensor=self.convert_to_tensor,
#      93 )
#      95 # Compute similarites using either cosine-similarity or dot product
#      96 cos_scores = self.score_functions[score_function](query_embeddings, sub_corpus_embeddings)
#
# File ~/miniconda3/lib/python3.11/site-packages/beir/retrieval/models/sentence_bert.py:105, in SentenceBERT.encode_corpus(self, corpus, batch_size, **kwargs)
#      98 def encode_corpus(
#      99     self,
#     100     corpus: list[dict[str, str]] | dict[str, list] | list[str],
#     101     batch_size: int = 8,
#     102     **kwargs,
#     103 ) -> list[Tensor] | np.ndarray | Tensor:
#     104     sentences = extract_corpus_sentences(corpus=corpus, sep=self.sep)
# --> 105     return self.doc_model.encode(
#     106         sentences,
#     107         prompt=self.doc_prefix,
#     108         prompt_name=self.doc_prompt_name,
#     109         batch_size=batch_size,
#     110         **kwargs,
#     111     )
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~/miniconda3/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)
#     257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:996, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     989 # Prepare head mask if needed
#     990 # 1.0 in head_mask indicate we keep the head
#     991 # attention_probs has shape bsz x n_heads x N x N
#     992 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     993 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     994 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 996 encoder_outputs = self.encoder(
#     997     embedding_output,
#     998     attention_mask=extended_attention_mask,
#     999     head_mask=head_mask,
#    1000     encoder_hidden_states=encoder_hidden_states,
#    1001     encoder_attention_mask=encoder_extended_attention_mask,
#    1002     past_key_values=past_key_values,
#    1003     use_cache=use_cache,
#    1004     output_attentions=output_attentions,
#    1005     output_hidden_states=output_hidden_states,
#    1006     return_dict=return_dict,
#    1007 )
#    1008 sequence_output = encoder_outputs[0]
#    1009 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:651, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     648 layer_head_mask = head_mask[i] if head_mask is not None else None
#     649 past_key_value = past_key_values[i] if past_key_values is not None else None
# --> 651 layer_outputs = layer_module(
#     652     hidden_states,
#     653     attention_mask,
#     654     layer_head_mask,
#     655     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     656     encoder_attention_mask=encoder_attention_mask,
#     657     past_key_value=past_key_value,
#     658     output_attentions=output_attentions,
#     659 )
#     661 hidden_states = layer_outputs[0]
#     662 if use_cache:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_layers.py:83, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      80         logger.warning(message)
#      82     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 83 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:553, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     541 def forward(
#     542     self,
#     543     hidden_states: torch.Tensor,
#    (...)
#     550 ) -> tuple[torch.Tensor]:
#     551     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     552     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 553     self_attention_outputs = self.attention(
#     554         hidden_states,
#     555         attention_mask,
#     556         head_mask,
#     557         output_attentions=output_attentions,
#     558         past_key_value=self_attn_past_key_value,
#     559     )
#     560     attention_output = self_attention_outputs[0]
#     562     # if decoder, the last output is tuple of self-attn cache
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:483, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     473 def forward(
#     474     self,
#     475     hidden_states: torch.Tensor,
#    (...)
#     481     output_attentions: Optional[bool] = False,
#     482 ) -> tuple[torch.Tensor]:
# --> 483     self_outputs = self.self(
#     484         hidden_states,
#     485         attention_mask,
#     486         head_mask,
#     487         encoder_hidden_states,
#     488         encoder_attention_mask,
#     489         past_key_value,
#     490         output_attentions,
#     491     )
#     492     attention_output = self.output(self_outputs[0], hidden_states)
#     493     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:408, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     400 # We dispatch to SDPA's Flash Attention or Efficient kernels via this `is_causal` if statement instead of an inline conditional assignment
#     401 # in SDPA to support both torch.compile's dynamic shapes and full graph options. An inline conditional prevents dynamic shapes from compiling.
#     402 # The tgt_len > 1 is necessary to match with AttentionMaskConverter.to_causal_4d that does not create
#     403 # a causal mask in case tgt_len == 1.
#     404 is_causal = (
#     405     True if self.is_decoder and not is_cross_attention and attention_mask is None and tgt_len > 1 else False
#     406 )
# --> 408 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     409     query_layer,
#     410     key_layer,
#     411     value_layer,
#     412     attn_mask=attention_mask,
#     413     dropout_p=self.dropout_prob if self.training else 0.0,
#     414     is_causal=is_causal,
#     415 )
#     417 attn_output = attn_output.transpose(1, 2)
#     418 attn_output = attn_output.reshape(bsz, tgt_len, self.all_head_size)
#
# KeyboardInterrupt:

# %%
rows = []

for ds_name, metrics in all_metrics.items():
    ndcg = metrics["ndcg"]
    recall = metrics["recall"]

    for k in K_VALUES:
        rows.append({
            "dataset": ds_name,
            "k": k,
            "nDCG": ndcg[k],
            "Recall": recall[k],
        })

df_results = pd.DataFrame(rows)
df_results
